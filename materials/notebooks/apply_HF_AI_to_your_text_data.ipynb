# %% [markdown]
# <a href="https://colab.research.google.com/github/motazsaad/Exploratory-Analysis-of-Big-Data/blob/main/apply_AI_to_your_text_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Load data
#
# https://huggingface.co/datasets/DSCI511G1/COP26_Energy_Transition_Tweets

# %%
import pandas as pd

df = pd.read_csv("hf://datasets/DSCI511G1/COP26_Energy_Transition_Tweets/energy_transition_tweets_final.csv")
df.head()
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
#                                             tweetURL              tweetID  \
# 0  https://twitter.com/thomascheneygpc/status/146...  1461120800350621700
# 1  https://twitter.com/alexizawadzki/status/14611...  1461118744613187585
# 2  https://twitter.com/getiftech/status/146111665...  1461116656986599433
# 3  https://twitter.com/KirkMMorrison/status/14611...  1461114703636140042
# 4  https://twitter.com/ColumbiaUEnergy/status/146...  1461114427466346499
#
#                         date  \
# 0  2021-11-17T23:55:19+00:00
# 1  2021-11-17T23:47:09+00:00
# 2  2021-11-17T23:38:51+00:00
# 3  2021-11-17T23:31:06+00:00
# 4  2021-11-17T23:30:00+00:00
#
#                                         tweetContent        userLocation  \
# 0  @sjmuir Why I like local Renewable Natural Gas...                 NaN
# 1  Nevada is critical towards the clean energy tr...   Greater Vancouver
# 2  COP26 Net Zero Commitments will Speed Energy T...                 NaN
# 3  @alanfryermedia You’re onto something! 🇨🇦 has ...    Calgary, Alberta
# 4  "The reality is that actions in this decade wi...  New York, New York
#
#    isUserVerified  replyCount  retweetCount  likeCount  quoteCount  \
# 0           False           0             0          0           0
# 1           False           0             1         21           0
# 2           False           0             0          0           0
# 3           False           0             1          5           0
# 4            True           0             1          3           1
#
#   tweetLanguage               sourceLabel  coordinates  place
# 0            en        Twitter for iPhone          NaN    NaN
# 1            en        Twitter for iPhone          NaN    NaN
# 2            en                TekieBoard          NaN    NaN
# 3            en        Twitter for iPhone          NaN    NaN
# 4            en  Twitter for Advertisers.          NaN    NaN

# %% [markdown]
# # emotion classification

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

emotion = pipeline("text-classification", model="j-hartmann/emotion-english-distilroberta-base")
# Out:
# config.json:   0%|          | 0.00/1.00k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/329M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/294 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/329M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Device set to use cpu

# %% [markdown]
# # test the model

# %%
emotion("I love NLP")
# Out:
# [{'label': 'joy', 'score': 0.9823769330978394}]

# %%
sample_df = df.sample(100)

# %%
# prompt: write code to get the emotion and the score of each tweet in the sample_df

import pandas as pd

# Assuming df and emotion are already defined as in the previous code

# Function to get emotion and score
def get_emotion(text):
    try:
        result = emotion(text)[0]
        return result['label'], result['score']
    except Exception as e:
        print(f"Error processing text: {text}, Error: {e}")
        return None, None


# Apply the function to the sample_df
sample_df[['emotion', 'score']] = sample_df['tweetContent'].apply(lambda x: pd.Series(get_emotion(x)))

# %%
# Display the updated DataFrame
sample_df[['tweetContent', 'emotion', 'score']]
# Out:
#                                             tweetContent  emotion     score
# 507    We believe that green hydrogen play an importa...     fear  0.767650
# 14888  Why Renewable Energy isn’t the Only Answer in ...     fear  0.980144
# 9527   @WorldBank’s Demetrios Papathanasiou highlight...     fear  0.889081
# 12255  Clean Hydrogen Emerging As Major Player In Ene...  neutral  0.533403
# 4400   @ABridgesAuthor @CaliforniaGlobe Great analysi...      joy  0.248345
# ...                                                  ...      ...       ...
# 12486  Commodity Tracker: big themes in energy and ra...     fear  0.640369
# 3598   @Malik956_ @HarrySilver17 @HermsTheWord @anasa...    anger  0.374063
# 13868  $XOM's Woods says its low-carbon strategy is t...  neutral  0.549391
# 3883   “Простой формулы 2+2 в устойчивом развитии нет...     fear  0.751661
# 4344   #Hydrogen and the energy transition. [FILM WIT...     fear  0.853731
#
# [100 rows x 3 columns]

# %%
# Save the DataFrame (replace 'sample_df.csv' with your desired file name)
sample_df.to_csv('sample_emotions.csv', index=False)

# %% [markdown]
# NER

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline

tokenizer = AutoTokenizer.from_pretrained("dslim/bert-base-NER")
model = AutoModelForTokenClassification.from_pretrained("dslim/bert-base-NER")

ner = pipeline("ner", model=model, tokenizer=tokenizer)
example = "My name is Wolfgang and I live in Berlin"

ner_results = ner(example)
print(ner_results)
# Out:
# Some weights of the model checkpoint at dslim/bert-base-NER were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use cpu
# [{'entity': 'B-PER', 'score': np.float32(0.9990139), 'index': 4, 'word': 'Wolfgang', 'start': 11, 'end': 19}, {'entity': 'B-LOC', 'score': np.float32(0.999645), 'index': 9, 'word': 'Berlin', 'start': 34, 'end': 40}]

# %%
# prompt: write code to extract people, locations and organization from tweetContent in the sample_df using ner model. add people, locations and organization as new columns

import pandas as pd
from transformers import pipeline
from transformers import AutoTokenizer, AutoModelForTokenClassification

# ... (previous code)

def extract_entities(text):
    try:
        results = ner(text)
        people = [result['word'] for result in results if 'PER' in result['entity'] ]
        locations = [result['word'] for result in results if 'LOC' in result['entity'] ]
        organizations = [result['word'] for result in results if 'ORG' in result['entity']]
        return people, locations, organizations
    except Exception as e:
        print(f"Error processing text: {text}, Error: {e}")
        return [], [], []

# Apply the function to the sample_df
sample_df[['people', 'locations', 'organizations']] = sample_df['tweetContent'].apply(lambda x: pd.Series(extract_entities(x)))

# Display the updated DataFrame
sample_df[['tweetContent', 'people', 'locations', 'organizations']]
# Out:
#                                             tweetContent  \
# 507    We believe that green hydrogen play an importa...
# 14888  Why Renewable Energy isn’t the Only Answer in ...
# 9527   @WorldBank’s Demetrios Papathanasiou highlight...
# 12255  Clean Hydrogen Emerging As Major Player In Ene...
# 4400   @ABridgesAuthor @CaliforniaGlobe Great analysi...
# ...                                                  ...
# 12486  Commodity Tracker: big themes in energy and ra...
# 3598   @Malik956_ @HarrySilver17 @HermsTheWord @anasa...
# 13868  $XOM's Woods says its low-carbon strategy is t...
# 3883   “Простой формулы 2+2 в устойчивом развитии нет...
# 4344   #Hydrogen and the energy transition. [FILM WIT...
#
#                                                   people  \
# 507                                                   []
# 14888                                        [##P, ##ec]
# 9527   [De, ##met, ##rio, ##s, Papa, ##than, ##asi, #...
# 12255                                                 []
# 4400                                                  []
# ...                                                  ...
# 12486                                                 []
# 3598                                        [Harry, ##S]
# 13868                                            [Woods]
# 3883                                                  []
# 4344                                                  []
#
#                           locations  \
# 507    [##ydro, Experience, Center]
# 14888                            []
# 9527                             []
# 12255                            []
# 4400                   [California]
# ...                             ...
# 12486                           [P]
# 3598                             []
# 13868                            []
# 3883                             []
# 4344                             []
#
#                                            organizations
# 507                      [Ki, All, ##ian, H, ##gen, ##Z]
# 14888                                    [Energy, Julie]
# 9527     [World, ##B, ##an, ##k, E, ##SM, ##AP, Climate]
# 12255                                                 []
# 4400   [AB, ##ridge, ##s, ##A, ##uth, ##or, ##G, ##lo...
# ...                                                  ...
# 12486  [##mm, ##od, ##ity, Track, ##latt, ##s, ##E, #...
# 3598                                                  []
# 13868                                                 []
# 3883                                                  []
# 4344                                                  []
#
# [100 rows x 4 columns]

# %%
sample_df.to_json('sample_emotions_ner.json')
